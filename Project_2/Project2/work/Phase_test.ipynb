# %%
import numpy as np
import matplotlib.pyplot as plt
import sounddevice as sd
import time


sr = 44100

t = np.arange( sr )/sr

# waveform 1
f1 = 300 # frequency
a1 = 0.5 # amplitude
p1 = np.pi # phase
s1 = a1*np.sin( 2*np.pi*f1*t+p1 )

# waveform 2
f2 = 450 # frequency
a2 = 0.3 # amplitude
p2 = 0 # phase

s2 = a2*np.sin( 2*np.pi*f2*t + 2*np.pi*f2*p2 )

s3 = s1 + s2

plt.grid(True)
plt.plot( t[:1000] , s1[:1000] )
# plt.plot( t[:1000] , s2[:1000] )
# plt.plot( t[:1000] , s3[:1000] )
plt.show()

# sd.play( s1 , sr )
# # time.sleep(1.5)
# sd.play( s2 , sr )
# # time.sleep(1.5)
# sd.play( s3 , sr )
